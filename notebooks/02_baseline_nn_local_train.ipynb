# %% [markdown]
# # Baseline NN Local Training

# %%
from src.model.train import train_model, save_artifacts
model, metrics = train_model('data/nb/data.csv', 'data/nb/data.csv', 'classification', epochs=1)
metrics
