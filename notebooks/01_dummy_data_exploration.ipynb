# %% [markdown]
# # Dummy Data Exploration

# %%
from src.data.generate_dummy import generate_dummy_dataset

meta = generate_dummy_dataset('data/nb', 1000, 'classification')
meta

# %%
import pandas as pd
pd.read_csv('data/nb/data.csv').head()
